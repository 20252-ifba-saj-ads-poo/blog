// %%
class Conta{
    int numero;
    String cliente;
    double saldo;
    double limite;
    
    void saca(double quantidade){//método
        double novoSaldo = this.saldo - quantidade;
        this.saldo = novoSaldo;
    }
    
    void deposita(double quantidade){//método
        this.saldo += quantidade;
    }
    public boolean equals(Conta outraConta) {
        return this.numero == outraConta.numero;
    }
    @Override
    public String toString() {
        return "Conta{" +
                "numero=" + numero + 
                ", cliente='" + cliente + "'}";
    }
}

// %%
Conta c1 = new Conta();
c1.cliente = "Leandro";    
c1.saldo = 100.0; 
c1.numero = 15;
Conta c2 = new Conta();    
c2.cliente = "Leandro";    
c2.saldo = 100.0;    
c2.numero = 15;
// Out:
// 15

// %%
c1
// Out:
// Conta{numero=15, cliente='Leandro'}
